# %%
import pandas as pd
import numpy as np
import ast
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
f = open("./data/datasets2/flights100_isClean.txt", "r")
flights_100_pred = f.read()
flights_100_pred = ast.literal_eval(flights_100_pred)
flights_100_pred = [eval(i) for i in flights_100_pred]
flights_100_pred = {'isClean': flights_100_pred}
flights_100_pred = pd.DataFrame(flights_100_pred)
display(flights_100_pred)
# Out:
#     isClean
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 95        0
# 96        0
# 97        1
# 98        1
# 99        1
#
# [100 rows x 1 columns]

# %%
flights_100_actual = pd.read_csv('./data/datasets2/flight_dirty.csv').loc[:99]
display(flights_100_actual)
# Out:
#                     src                      flight  \
# 0                    ua  2011-12-01-UA-2708-EWR-CLT
# 1       airtravelcenter  2011-12-01-UA-2708-EWR-CLT
# 2            myrateplan  2011-12-01-UA-2708-EWR-CLT
# 3           helloflight  2011-12-01-UA-2708-EWR-CLT
# 4             flytecomm  2011-12-01-UA-2708-EWR-CLT
# ..                  ...                         ...
# 95          flightaware   2011-12-01-AA-222-LAX-BOS
# 96         wunderground   2011-12-01-AA-222-LAX-BOS
# 97              flights   2011-12-01-AA-222-LAX-BOS
# 98  businesstravellogue   2011-12-01-AA-222-LAX-BOS
# 99        flylouisville   2011-12-01-AA-222-LAX-BOS
#
#                scheduled_dept                actual_dept dept_gate  \
# 0          Thu- Dec 1 2:55 PM         Thu- Dec 1 2:55 PM       A37
# 1                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 2                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 3                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 4                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# ..                        ...                        ...       ...
# 95     2011-12-01 07:10AM PST     2011-12-01 07:32AM PST      47A
# 96     2011-12-01 07:10AM PST     2011-12-01 07:32AM PST      47A
# 97  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
# 98  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
# 99  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
#
#             scheduled_arrival             actual_arrival arrival_gate  isClean
# 0          Thu- Dec 1 4:53 PM         Thu- Dec 1 4:44 PM           C5        1
# 1                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 2                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 3                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 4                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# ..                        ...                        ...          ...      ...
# 95     2011-12-01 02:52PM EST     2011-12-01 03:12PM EST         B36         0
# 96     2011-12-01 02:52PM EST     2011-12-01 03:12PM EST         B36         0
# 97  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
# 98  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
# 99  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
#
# [100 rows x 9 columns]

# %%
flights100_confusion = metrics.confusion_matrix(flights_100_actual['isClean'],flights_100_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = flights100_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(flights_100_actual['isClean'],flights_100_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84        96
#            1       0.13      1.00      0.23         4
#
#     accuracy                           0.73       100
#    macro avg       0.56      0.86      0.53       100
# weighted avg       0.97      0.73      0.81       100

# %%
f = open("./data/datasets2/hospital100_isClean.txt", "r")
hospital_100_pred = f.read()
hospital_100_pred = ast.literal_eval(hospital_100_pred)
hospital_100_pred = [eval(i) for i in hospital_100_pred]
hospital_100_pred = {'isClean': hospital_100_pred}
hospital_100_pred = pd.DataFrame(hospital_100_pred)
display(hospital_100_pred)
# Out:
#     isClean
# 0         1
# 1         0
# 2         1
# 3         1
# 4         0
# ..      ...
# 95        1
# 96        1
# 97        1
# 98        1
# 99        1
#
# [100 rows x 1 columns]

# %%
hospital_100_actual = pd.read_csv('./data/datasets2/hospital_100_dirty.csv')
display(hospital_100_actual)
# Out:
#    ProviderNumber                      HospitalName  \
# 0           10018  callahan eye foundation hospital
# 1           1xx19    helen keller memorial hospital
# 2           10019    helen keller memorial hospital
# 3           10001  southeast alabama medical center
# 4           10001  southeast alabama medical center
# ..            ...                               ...
# 95          10050                st vincents bxount
# 96          10050                st vincents blount
# 97          10050                st vincents blount
# 98          10050                st vincents blount
# 99          10050                st vincents blount
#
#                         Address1  Address2  Address3        City State  \
# 0           1720 university blvd       NaN       NaN  birmingham    al
# 1   1300 south montgomery avenue       NaN       NaN   sheffield    al
# 2   1300 south montgomery avenue       NaN       NaN   sheffield    al
# 3         1108 ross clark circle       NaN       NaN      dothan    al
# 4         1108 ross clark circle       NaN       NaN      dothan    al
# ..                           ...       ...       ...         ...   ...
# 95           150 gilbreath drive       NaN       NaN     oneonta    al
# 96           150 gilbreath drive       NaN       NaN     oneonta    al
# 97           150 gilbreath drive       NaN       NaN     oneonta    al
# 98           150 gilbreath drive       NaN       NaN     oneonta    al
# 99           150 gilbreath drive       NaN       NaN     oneonta    al
#
#    ZipCode CountyName PhoneNumber          HospitalType  \
# 0    35233  jefferson  2053258100  acute care hospitals
# 1    35660  jefferson  2563864556  acute care hospitals
# 2    35660  jefferson  2563864556  acute care hospitals
# 3    36302    houston  3347938701  acute care hospitals
# 4    36302    houston  xx479x8701  acute care hospitals
# ..     ...        ...         ...                   ...
# 95   35121     blount  2052743000  acute care hospitals
# 96   35121     blount  2052743000  acute care hospitals
# 97   35121     blount  2052743000  acute care hospitals
# 98   35121     blount  2052743000  acute care hospitals
# 99   35121     blount  2052743000  acute care hospitals
#
#                                   HospitalOwner EmergencyService  \
# 0                voluntary non-profit - private              yes
# 1   government - hospital district or authority              yes
# 2   government - hospital district or authority              yes
# 3   government - hospital district or authority              yes
# 4   government - hospital district or authority              yes
# ..                                          ...              ...
# 95               voluntary non-profit - private              yes
# 96               voluntary non-profit - private              yes
# 97               voluntary non-profit - private              yes
# 98               voluntary non-profit - private              yes
# 99               voluntary non-profit - private              yes
#
#                         Condition  MeasureCode  \
# 0   surgical infection prevention   scip-inf-6
# 1                    heart attack       ami-7a
# 2                   heart failure         hf-4
# 3                       pneumonia         pn-6
# 4   surgical infection prevention  scip-card-2
# ..                            ...          ...
# 95                  heart failure         hf-1
# 96                      pneumonia         pn-2
# 97                      pneumonia         pn-6
# 98  surgical infection prevention  scip-card-2
# 99  surgical infection prevention   scip-inf-2
#
#                                           MeasureName Score        Sample  \
# 0   surgery patients needing hair removed from the...   NaN           NaN
# 1   heart attack patients given fibrinolytic medic...   NaN    0 patients
# 2   heart failure patients given smoking cessation...  100%   41 patients
# 3   pneumonia patients given the most appropriate ...   80%  147 patients
# 4   surgery patients who were taking heart drugs c...   72%   79 patients
# ..                                                ...   ...           ...
# 95  heart failure patients given discharge instruc...   50%   24 patients
# 96  pneumonia patients assessed and given pneumoco...   74%   92 patients
# 97  pneumonia patients given the most appropriate ...   77%   74 patients
# 98  surgery pxtients who were txking hexrt drugs c...   25%    8 patients
# 99  surgery patients who were given the  right kin...   88%   25 patients
#
#           Stateavg  isClean
# 0    al_scip-inf-6        1
# 1        al_ami-7a        0
# 2          al_hf-4        1
# 3          al_pn-6        1
# 4   al_scip-card-2        0
# ..             ...      ...
# 95         al_hf-1        0
# 96         al_pn-2        1
# 97         al_pn-6        1
# 98  al_scip-card-2        0
# 99   al_scip-inf-2        1
#
# [100 rows x 20 columns]

# %%
hospital100_confusion = metrics.confusion_matrix(hospital_100_actual['isClean'],hospital_100_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = hospital100_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(hospital_100_actual['isClean'],hospital_100_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.42      0.57        45
#            1       0.67      0.95      0.78        55
#
#     accuracy                           0.71       100
#    macro avg       0.77      0.68      0.67       100
# weighted avg       0.76      0.71      0.69       100

# %% [markdown]
# adults

# %%
f = open("./data/datasets2/adults_isClean.txt", "r")
adults_pred = f.read()
adults_pred = ast.literal_eval(adults_pred)
adults_pred = [eval(i) for i in adults_pred]
adults_pred = {'isClean': adults_pred}
adults_pred = pd.DataFrame(adults_pred)
display(adults_pred)
# Out:
#      isClean
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0
# ..       ...
# 828        1
# 829        1
# 830        1
# 831        1
# 832        1
#
# [833 rows x 1 columns]

# %%
adults_actual = pd.read_csv('./data/datasets2/adults_dirty.csv').drop('row_id',axis=1)
adults_actual = adults_actual[:833]
display(adults_actual)
# Out:
#        age workclass     education       maritalstatus         occupation  \
# 0    31-50   Private   Prof-school       Never-married     Prof-specialty
# 1      >50   Private       HS-grad  Married-civ-spouse       Craft-repair
# 2      >50   Private  Some-college  Married-civ-spouse    Exec-managerial
# 3    22-30   Private       HS-grad       Never-married  Handlers-cleaners
# 4    31-50   Private       Masters                   ?     Prof-specialty
# ..     ...       ...           ...                 ...                ...
# 828  18-21   Private  Some-college       Never-married       Adm-clerical
# 829  18-21   Private  Some-college       Never-married       Adm-clerical
# 830  18-21   Private  Some-college       Never-married      Other-service
# 831  18-21   Private  Some-college       Never-married  Handlers-cleaners
# 832  18-21   Private  Some-college       Never-married              Sales
#
#       relationship   race     sex hoursperweek        country       income  \
# 0    Not-in-family  White  Female           40  United-States  MoreThan50K
# 1          Husband  White    Male           16  United-States  LessThan50K
# 2          Husband  White    Male           55            NaN  MoreThan50K
# 3        Own-child  White    Male           40  United-States  LessThan50K
# 4          Husband  White    Male           42  United-States  MoreThan50K
# ..             ...    ...     ...          ...            ...          ...
# 828      Own-child  White    Male           30  United-States  LessThan50K
# 829      Own-child  White    Male           40  United-States  LessThan50K
# 830      Own-child  White    Male        18-21  United-States  LessThan50K
# 831      Own-child  White    Male           40  United-States  LessThan50K
# 832      Own-child  White    Male           35  United-States  LessThan50K
#
#      isClean
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0
# ..       ...
# 828        1
# 829        1
# 830        1
# 831        1
# 832        1
#
# [833 rows x 12 columns]

# %%
adults_confusion = metrics.confusion_matrix(adults_actual['isClean'],adults_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = adults_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(adults_actual['isClean'],adults_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.48      0.55        99
#            1       0.93      0.96      0.95       734
#
#     accuracy                           0.91       833
#    macro avg       0.79      0.72      0.75       833
# weighted avg       0.90      0.91      0.90       833

# %%
f = open("./data/datasets2/flights100_isClean_full_temp1.txt", "r")
flights_100_pred = f.read()
flights_100_pred = ast.literal_eval(flights_100_pred)
flights100_isCleanFull_pred = pd.DataFrame(columns=['isClean'])
flights_100_actual = pd.read_csv('./data/datasets2/flight_dirty.csv')
flights_100_actual = flights_100_actual.loc[:99]
display(flights_100_actual)
# Out:
#                     src                      flight  \
# 0                    ua  2011-12-01-UA-2708-EWR-CLT
# 1       airtravelcenter  2011-12-01-UA-2708-EWR-CLT
# 2            myrateplan  2011-12-01-UA-2708-EWR-CLT
# 3           helloflight  2011-12-01-UA-2708-EWR-CLT
# 4             flytecomm  2011-12-01-UA-2708-EWR-CLT
# ..                  ...                         ...
# 95          flightaware   2011-12-01-AA-222-LAX-BOS
# 96         wunderground   2011-12-01-AA-222-LAX-BOS
# 97              flights   2011-12-01-AA-222-LAX-BOS
# 98  businesstravellogue   2011-12-01-AA-222-LAX-BOS
# 99        flylouisville   2011-12-01-AA-222-LAX-BOS
#
#                scheduled_dept                actual_dept dept_gate  \
# 0          Thu- Dec 1 2:55 PM         Thu- Dec 1 2:55 PM       A37
# 1                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 2                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 3                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# 4                         NaN   12/1/11 3:04 PM (-05:00)       NaN
# ..                        ...                        ...       ...
# 95     2011-12-01 07:10AM PST     2011-12-01 07:32AM PST      47A
# 96     2011-12-01 07:10AM PST     2011-12-01 07:32AM PST      47A
# 97  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
# 98  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
# 99  07:10 AM  Thu 01-Dec-2011  07:31 AM  Thu 01-Dec-2011       47A
#
#             scheduled_arrival             actual_arrival arrival_gate  isClean
# 0          Thu- Dec 1 4:53 PM         Thu- Dec 1 4:44 PM           C5        1
# 1                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 2                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 3                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# 4                         NaN   12/1/11 4:22 PM (-05:00)          NaN        0
# ..                        ...                        ...          ...      ...
# 95     2011-12-01 02:52PM EST     2011-12-01 03:12PM EST         B36         0
# 96     2011-12-01 02:52PM EST     2011-12-01 03:12PM EST         B36         0
# 97  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
# 98  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
# 99  03:30 PM  Thu 01-Dec-2011  03:14 PM  Thu 01-Dec-2011          B36        0
#
# [100 rows x 9 columns]

# %%
for tup_pred in flights_100_pred:
    if len(tup_pred) != len(flights_100_actual.columns)-1:
        for _ in range(len(flights_100_actual.columns)-1):
            flights100_isCleanFull_pred.loc[len(flights100_isCleanFull_pred.index)] = [-1]
    else:
        for char in tup_pred:
            flights100_isCleanFull_pred.loc[len(flights100_isCleanFull_pred.index)] = [int(char)]
display(flights100_isCleanFull_pred)
# Out:
#      isClean
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 795        1
# 796        1
# 797        1
# 798        1
# 799        1
#
# [800 rows x 1 columns]

# %%
flights_100_clean = pd.read_csv('./data/datasets2/flight_clean.csv')
flights_100_clean = flights_100_clean.loc[:99]
display(flights_100_clean)
# Out:
#                     src                      flight       scheduled_dept  \
# 0                    ua  2011-12-01-UA-2708-EWR-CLT   Thu- Dec 1 2:55 PM
# 1       airtravelcenter  2011-12-01-UA-2708-EWR-CLT   Thu- Dec 1 2:55 PM
# 2            myrateplan  2011-12-01-UA-2708-EWR-CLT   Thu- Dec 1 2:55 PM
# 3           helloflight  2011-12-01-UA-2708-EWR-CLT   Thu- Dec 1 2:55 PM
# 4             flytecomm  2011-12-01-UA-2708-EWR-CLT   Thu- Dec 1 2:55 PM
# ..                  ...                         ...                  ...
# 95          flightaware   2011-12-01-AA-222-LAX-BOS  12/01/2011 07:10 AM
# 96         wunderground   2011-12-01-AA-222-LAX-BOS  12/01/2011 07:10 AM
# 97              flights   2011-12-01-AA-222-LAX-BOS  12/01/2011 07:10 AM
# 98  businesstravellogue   2011-12-01-AA-222-LAX-BOS  12/01/2011 07:10 AM
# 99        flylouisville   2011-12-01-AA-222-LAX-BOS  12/01/2011 07:10 AM
#
#             actual_dept dept_gate    scheduled_arrival       actual_arrival  \
# 0    Thu- Dec 1 2:55 PM       A37   Thu- Dec 1 4:53 PM   Thu- Dec 1 4:44 PM
# 1    Thu- Dec 1 2:55 PM       A37   Thu- Dec 1 4:53 PM   Thu- Dec 1 4:44 PM
# 2    Thu- Dec 1 2:55 PM       A37   Thu- Dec 1 4:53 PM   Thu- Dec 1 4:44 PM
# 3    Thu- Dec 1 2:55 PM       A37   Thu- Dec 1 4:53 PM   Thu- Dec 1 4:44 PM
# 4    Thu- Dec 1 2:55 PM       A37   Thu- Dec 1 4:53 PM   Thu- Dec 1 4:44 PM
# ..                  ...       ...                  ...                  ...
# 95  12/01/2011 07:31 AM       47A  12/01/2011 03:30 PM  12/01/2011 03:14 PM
# 96  12/01/2011 07:31 AM       47A  12/01/2011 03:30 PM  12/01/2011 03:14 PM
# 97  12/01/2011 07:31 AM       47A  12/01/2011 03:30 PM  12/01/2011 03:14 PM
# 98  12/01/2011 07:31 AM       47A  12/01/2011 03:30 PM  12/01/2011 03:14 PM
# 99  12/01/2011 07:31 AM       47A  12/01/2011 03:30 PM  12/01/2011 03:14 PM
#
#    arrival_gate
# 0            C5
# 1            C5
# 2            C5
# 3            C5
# 4            C5
# ..          ...
# 95          B36
# 96          B36
# 97          B36
# 98          B36
# 99          B36
#
# [100 rows x 8 columns]

# %%
flights100_isCleanFull_actual = pd.DataFrame(columns=['isClean'])
for ind in flights_100_clean.index:
    for column in flights_100_clean.columns:
        if str(flights_100_clean[column][ind]) == str(flights_100_actual[column][ind]):
            flights100_isCleanFull_actual.loc[len(flights100_isCleanFull_actual.index)] = [1]
        else:
            flights100_isCleanFull_actual.loc[len(flights100_isCleanFull_actual.index)] = [0]
    
display(flights100_isCleanFull_actual)
# Out:
#      isClean
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 795        0
# 796        1
# 797        0
# 798        0
# 799        1
#
# [800 rows x 1 columns]

# %%
for ind in range(len(flights100_isCleanFull_pred.index)):
    if flights100_isCleanFull_pred['isClean'][ind] == -1:
        flights100_isCleanFull_pred['isClean'][ind] = 0 if flights100_isCleanFull_actual['isClean'][ind] == 1 else 0

# %%
flights_full_confusion = metrics.confusion_matrix(flights100_isCleanFull_actual['isClean'],flights100_isCleanFull_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = flights_full_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(flights100_isCleanFull_actual['isClean'],flights100_isCleanFull_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.33      0.46       549
#            1       0.34      0.76      0.47       251
#
#     accuracy                           0.46       800
#    macro avg       0.54      0.54      0.46       800
# weighted avg       0.62      0.46      0.46       800

# %%
f = open("./data/datasets2/adults100_isClean_full_temp1.txt", "r")
adults_100_pred = f.read()
adults_100_pred = ast.literal_eval(adults_100_pred)
adults100_isCleanFull_pred = pd.DataFrame(columns=['isClean'])
adults_100_actual = pd.read_csv('./data/datasets2/adults_dirty.csv').drop('row_id',axis=1)
adults_100_actual = adults_100_actual.loc[:99]
display(adults_100_actual)
# Out:
#       age         workclass     education       maritalstatus  \
# 0   31-50           Private   Prof-school       Never-married
# 1     >50           Private       HS-grad  Married-civ-spouse
# 2     >50           Private  Some-college  Married-civ-spouse
# 3   22-30           Private       HS-grad       Never-married
# 4   31-50           Private       Masters                   ?
# ..    ...               ...           ...                 ...
# 95  18-21           Private  Some-college       Never-married
# 96  22-30           Private       HS-grad  Married-cmv-spoude
# 97    >50         Local-gov       HS-grad  Married-civ-spouse
# 98  31-50           Private  Some-college  Married-civ-spouse
# 99  31-50  Self-emp-not-inc     Bachelors  Married-civ-spouse
#
#            occupation   relationship                race     sex hoursperweek  \
# 0      Prof-specialty  Not-in-family               White  Female           40
# 1        Craft-repair        Husband               White    Male           16
# 2     Exec-managerial        Husband               White    Male           55
# 3   Handlers-cleaners      Own-child               White    Male           40
# 4      Prof-specialty        Husband               White    Male           42
# ..                ...            ...                 ...     ...          ...
# 95       Adm-clerical      Own-child               White  Female           40
# 96       Craft-repair      Own-child  Asian-Pac-Islander    Male           40
# 97   Transport-moving        Husband               White    Male           40
# 98              Sales        Husband               White    Male           90
# 99     Prof-specialty        Husband               White    Male           30
#
#           country       income  isClean
# 0   United-States  MoreThan50K        1
# 1   United-States  LessThan50K        1
# 2             NaN  MoreThan50K        0
# 3   United-States  LessThan50K        1
# 4   United-States  MoreThan50K        0
# ..            ...          ...      ...
# 95  United-States  LessThan50K        1
# 96  United-States  LessThan50K        0
# 97  United-States  LessThan50K        1
# 98  United-States  MoreThan50K        1
# 99  United-States  LessThan50K        1
#
# [100 rows x 12 columns]

# %%
for tup_pred in adults_100_pred:
    if len(tup_pred) != len(adults_100_actual.columns)-1:
        for _ in range(len(adults_100_actual.columns)-1):
            adults100_isCleanFull_pred.loc[len(adults100_isCleanFull_pred.index)] = [-1]
    else:
        for char in tup_pred:
            adults100_isCleanFull_pred.loc[len(adults100_isCleanFull_pred.index)] = [int(char)]
display(adults100_isCleanFull_pred)
# Out:
#       isClean
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1095        1
# 1096        1
# 1097        1
# 1098        1
# 1099        1
#
# [1100 rows x 1 columns]

# %%
adults_100_clean = pd.read_csv('./data/datasets2/adults_clean.csv').drop('row_id',axis=1)
adults_100_clean = adults_100_clean.loc[:99]
display(adults_100_clean)
# Out:
#       age         workclass     education       maritalstatus  \
# 0   31-50           Private   Prof-school       Never-married
# 1     >50           Private       HS-grad  Married-civ-spouse
# 2     >50           Private  Some-college  Married-civ-spouse
# 3   22-30           Private       HS-grad       Never-married
# 4   31-50           Private       Masters  Married-civ-spouse
# ..    ...               ...           ...                 ...
# 95  18-21           Private  Some-college       Never-married
# 96  22-30           Private       HS-grad  Married-civ-spouse
# 97    >50         Local-gov       HS-grad  Married-civ-spouse
# 98  31-50           Private  Some-college  Married-civ-spouse
# 99  31-50  Self-emp-not-inc     Bachelors  Married-civ-spouse
#
#            occupation   relationship                race     sex hoursperweek  \
# 0      Prof-specialty  Not-in-family               White  Female           40
# 1        Craft-repair        Husband               White    Male           16
# 2     Exec-managerial        Husband               White    Male           55
# 3   Handlers-cleaners      Own-child               White    Male           40
# 4      Prof-specialty        Husband               White    Male           42
# ..                ...            ...                 ...     ...          ...
# 95       Adm-clerical      Own-child               White  Female           40
# 96       Craft-repair      Own-child  Asian-Pac-Islander    Male           40
# 97   Transport-moving        Husband               White    Male           40
# 98              Sales        Husband               White    Male           90
# 99     Prof-specialty        Husband               White    Male           30
#
#           country       income
# 0   United-States  MoreThan50K
# 1   United-States  LessThan50K
# 2   United-States  MoreThan50K
# 3   United-States  LessThan50K
# 4   United-States  MoreThan50K
# ..            ...          ...
# 95  United-States  LessThan50K
# 96  United-States  LessThan50K
# 97  United-States  LessThan50K
# 98  United-States  MoreThan50K
# 99  United-States  LessThan50K
#
# [100 rows x 11 columns]

# %%
adults100_isCleanFull_actual = pd.DataFrame(columns=['isClean'])
for ind in adults_100_clean.index:
    for column in adults_100_clean.columns:
        if str(adults_100_clean[column][ind]) == str(adults_100_actual[column][ind]):
            adults100_isCleanFull_actual.loc[len(adults100_isCleanFull_actual.index)] = [1]
        else:
            adults100_isCleanFull_actual.loc[len(adults100_isCleanFull_actual.index)] = [0]
    
display(adults100_isCleanFull_actual)
# Out:
#       isClean
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1095        1
# 1096        1
# 1097        1
# 1098        1
# 1099        1
#
# [1100 rows x 1 columns]

# %%
for ind in range(len(adults100_isCleanFull_pred.index)):
    if adults100_isCleanFull_pred['isClean'][ind] == -1:
        adults100_isCleanFull_pred['isClean'][ind] = 0 if adults100_isCleanFull_actual['isClean'][ind] == 1 else 0

# %%
adults_full_confusion = metrics.confusion_matrix(adults100_isCleanFull_actual['isClean'],adults100_isCleanFull_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = adults_full_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(adults100_isCleanFull_actual['isClean'],adults100_isCleanFull_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.21      0.18        14
#            1       0.99      0.99      0.99      1086
#
#     accuracy                           0.98      1100
#    macro avg       0.57      0.60      0.58      1100
# weighted avg       0.98      0.98      0.98      1100

# %% [markdown]
# hospital

# %%
f = open("./data/datasets2/hospital100_isClean_full_temp1.txt", "r")
hospital_100_pred = f.read()
hospital_100_pred = ast.literal_eval(hospital_100_pred)
hospital100_isCleanFull_pred = pd.DataFrame(columns=['isClean'])
hospital_100_actual = pd.read_csv('./data/datasets2/hospital_100_dirty.csv')
# display(hospital_100_actual)

# %%
for tup_pred in hospital_100_pred:
    if len(tup_pred) != len(hospital_100_actual.columns)-1:
        for _ in range(len(hospital_100_actual.columns)-1):
            hospital100_isCleanFull_pred.loc[len(hospital100_isCleanFull_pred.index)] = [-1]
    else:
        for char in tup_pred:
            hospital100_isCleanFull_pred.loc[len(hospital100_isCleanFull_pred.index)] = [int(char)]
display(hospital100_isCleanFull_pred)
# Out:
#       isClean
# 0           1
# 1           1
# 2           0
# 3           1
# 4           1
# ...       ...
# 1895       -1
# 1896       -1
# 1897       -1
# 1898       -1
# 1899       -1
#
# [1900 rows x 1 columns]

# %%
hospital_100_clean = pd.read_csv('./data/datasets2/hospital_100_clean.csv')
display(hospital_100_clean)
# Out:
#     ProviderNumber                      HospitalName  \
# 0            10018  callahan eye foundation hospital
# 1            10019    helen keller memorial hospital
# 2            10019    helen keller memorial hospital
# 3            10001  southeast alabama medical center
# 4            10001  southeast alabama medical center
# ..             ...                               ...
# 95           10050                st vincents blount
# 96           10050                st vincents blount
# 97           10050                st vincents blount
# 98           10050                st vincents blount
# 99           10050                st vincents blount
#
#                         Address1  Address2  Address3        City State  \
# 0           1720 university blvd       NaN       NaN  birmingham    al
# 1   1300 south montgomery avenue       NaN       NaN   sheffield    al
# 2   1300 south montgomery avenue       NaN       NaN   sheffield    al
# 3         1108 ross clark circle       NaN       NaN      dothan    al
# 4         1108 ross clark circle       NaN       NaN      dothan    al
# ..                           ...       ...       ...         ...   ...
# 95           150 gilbreath drive       NaN       NaN     oneonta    al
# 96           150 gilbreath drive       NaN       NaN     oneonta    al
# 97           150 gilbreath drive       NaN       NaN     oneonta    al
# 98           150 gilbreath drive       NaN       NaN     oneonta    al
# 99           150 gilbreath drive       NaN       NaN     oneonta    al
#
#     ZipCode CountyName  PhoneNumber          HospitalType  \
# 0     35233  jefferson   2053258100  acute care hospitals
# 1     35660  jefferson   2563864556  acute care hospitals
# 2     35660  jefferson   2563864556  acute care hospitals
# 3     36302    houston   3347938701  acute care hospitals
# 4     36302    houston   3347938701  acute care hospitals
# ..      ...        ...          ...                   ...
# 95    35121     blount   2052743000  acute care hospitals
# 96    35121     blount   2052743000  acute care hospitals
# 97    35121     blount   2052743000  acute care hospitals
# 98    35121     blount   2052743000  acute care hospitals
# 99    35121     blount   2052743000  acute care hospitals
#
#                                   HospitalOwner EmergencyService  \
# 0                voluntary non-profit - private              yes
# 1   government - hospital district or authority              yes
# 2   government - hospital district or authority              yes
# 3   government - hospital district or authority              yes
# 4   government - hospital district or authority              yes
# ..                                          ...              ...
# 95               voluntary non-profit - private              yes
# 96               voluntary non-profit - private              yes
# 97               voluntary non-profit - private              yes
# 98               voluntary non-profit - private              yes
# 99               voluntary non-profit - private              yes
#
#                         Condition  MeasureCode  \
# 0   surgical infection prevention   scip-inf-6
# 1                    heart attack       ami-7a
# 2                   heart failure         hf-4
# 3                       pneumonia         pn-6
# 4   surgical infection prevention  scip-card-2
# ..                            ...          ...
# 95                  heart failure         hf-1
# 96                      pneumonia         pn-2
# 97                      pneumonia         pn-6
# 98  surgical infection prevention  scip-card-2
# 99  surgical infection prevention   scip-inf-2
#
#                                           MeasureName Score        Sample  \
# 0   surgery patients needing hair removed from the...   NaN           NaN
# 1   heart attack patients given fibrinolytic medic...   NaN    0 patients
# 2   heart failure patients given smoking cessation...  100%   41 patients
# 3   pneumonia patients given the most appropriate ...   80%  147 patients
# 4   surgery patients who were taking heart drugs c...   72%   79 patients
# ..                                                ...   ...           ...
# 95  heart failure patients given discharge instruc...   50%   24 patients
# 96  pneumonia patients assessed and given pneumoco...   74%   92 patients
# 97  pneumonia patients given the most appropriate ...   77%   74 patients
# 98  surgery patients who were taking heart drugs c...   25%    8 patients
# 99  surgery patients who were given the  right kin...   88%   25 patients
#
#           Stateavg
# 0    al_scip-inf-6
# 1        al_ami-7a
# 2          al_hf-4
# 3          al_pn-6
# 4   al_scip-card-2
# ..             ...
# 95         al_hf-1
# 96         al_pn-2
# 97         al_pn-6
# 98  al_scip-card-2
# 99   al_scip-inf-2
#
# [100 rows x 19 columns]

# %%
hospital100_isCleanFull_actual = pd.DataFrame(columns=['isClean'])
for ind in hospital_100_clean.index:
    for column in hospital_100_clean.columns:
        if str(hospital_100_clean[column][ind]) == str(hospital_100_actual[column][ind]):
            hospital100_isCleanFull_actual.loc[len(hospital100_isCleanFull_actual.index)] = [1]
        else:
            hospital100_isCleanFull_actual.loc[len(hospital100_isCleanFull_actual.index)] = [0]
    
display(hospital100_isCleanFull_actual)
# Out:
#       isClean
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1895        1
# 1896        1
# 1897        1
# 1898        1
# 1899        1
#
# [1900 rows x 1 columns]

# %%
for ind in range(len(hospital100_isCleanFull_pred.index)):
    if hospital100_isCleanFull_pred['isClean'][ind] == -1:
        hospital100_isCleanFull_pred['isClean'][ind] = 0 if hospital100_isCleanFull_actual['isClean'][ind] == 1 else 0

# %%
hospital_full_confusion = metrics.confusion_matrix(hospital100_isCleanFull_actual['isClean'],hospital100_isCleanFull_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = hospital_full_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(hospital100_isCleanFull_actual['isClean'],hospital100_isCleanFull_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.02      0.10      0.04        59
#            1       0.97      0.87      0.92      1841
#
#     accuracy                           0.85      1900
#    macro avg       0.50      0.49      0.48      1900
# weighted avg       0.94      0.85      0.89      1900

# %%
total_full_pred = pd.DataFrame()
total_full_pred = total_full_pred.append(hospital100_isCleanFull_pred).append(adults100_isCleanFull_pred).append(flights100_isCleanFull_pred)
total_full_pred = total_full_pred.reset_index().drop('index',axis=1)
total_full_actual = pd.DataFrame()
total_full_actual = total_full_actual.append(hospital100_isCleanFull_actual).append(adults100_isCleanFull_actual).append(flights100_isCleanFull_actual)
total_full_actual = total_full_actual.reset_index().drop('index',axis=1)
# Out:
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_pred = total_full_pred.append(hospital100_isCleanFull_pred).append(adults100_isCleanFull_pred).append(flights100_isCleanFull_pred)
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_pred = total_full_pred.append(hospital100_isCleanFull_pred).append(adults100_isCleanFull_pred).append(flights100_isCleanFull_pred)
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_pred = total_full_pred.append(hospital100_isCleanFull_pred).append(adults100_isCleanFull_pred).append(flights100_isCleanFull_pred)
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_actual = total_full_actual.append(hospital100_isCleanFull_actual).append(adults100_isCleanFull_actual).append(flights100_isCleanFull_actual)
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_actual = total_full_actual.append(hospital100_isCleanFull_actual).append(adults100_isCleanFull_actual).append(flights100_isCleanFull_actual)
# C:\Users\reece\AppData\Local\Temp\ipykernel_57584\2470242155.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_full_actual = total_full_actual.append(hospital100_isCleanFull_actual).append(adults100_isCleanFull_actual).append(flights100_isCleanFull_actual)

# %%
for ind in range(len(total_full_pred.index)):
    if total_full_pred['isClean'][ind] == -1:
        total_full_pred['isClean'][ind] = 0 if total_full_actual['isClean'][ind] == 1 else 0

# %%
total_full_confusion = metrics.confusion_matrix(total_full_actual['isClean'],total_full_pred['isClean'])
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = total_full_confusion, display_labels = [0, 1]) 
cm_display.plot()
plt.show()

# %%
print(metrics.classification_report(total_full_actual['isClean'],total_full_pred['isClean']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.31      0.34       622
#            1       0.87      0.90      0.88      3178
#
#     accuracy                           0.80      3800
#    macro avg       0.62      0.60      0.61      3800
# weighted avg       0.79      0.80      0.79      3800
